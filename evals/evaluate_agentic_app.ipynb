# %%
import os
import json
from azure.ai.evaluation import (
    evaluate, 
    IntentResolutionEvaluator,
    ToolCallAccuracyEvaluator,
    TaskAdherenceEvaluator,
    AzureOpenAIModelConfiguration,
)
from pprint import pprint
from dotenv import load_dotenv

load_dotenv('../.env')

model_config = AzureOpenAIModelConfiguration(
    azure_endpoint=os.environ.get("AZURE_OPENAI_ENDPOINT"),
    azure_deployment=os.environ.get("AZURE_OPENAI_GPT4o_DEPLOYMENT"),
    api_key=os.environ.get("AZURE_OPENAI_API_KEY"),
    api_version=os.environ.get("AZURE_OPENAI_API_VERSION"),
)
file_path = "evaluation_dataset.jsonl"

# %%
tool_definitions=[
    {
        "name": "BookingPlugin-check_availability",
        "description": "Check if a room is available on a certain date.",
        "parameters": {
            "type": "object",
            "properties": {
                "room_type": {
                    "type": "string",
                    "description": "Type of room."
                },
                "date": {
                    "type": "string",
                    "description": "Booking date in YYYY-MM-DD format."
                }
            }
        }
    },
    {
        "name": "BookingPlugin-confirm_booking",
        "description": "Confirm booking and reduce room count.",
        "parameters": {
            "type": "object",
            "properties": {
                "room_type": {
                    "type": "string",
                    "description": "Type of room."
                },
                "date": {
                    "type": "string",
                    "description": "Booking date in YYYY-MM-DD format."
                },
                "count": {
                    "type": "integer",
                    "description": "Number of rooms to book."
                }
            }
        }
    },
    {
        "name": "DiningPlugin-get_specials",
        "description": "Provides today's dining specials.",
        "parameters": {
            "type": "object",
            "properties": {}
        }
    },
    {
        "name": "DiningPlugin-get_item_price",
        "description": "Provides the price of a specified menu item.",
        "parameters": {
            "type": "object",
            "properties": {
                "menu_item": {
                    "type": "string",
                    "description": "Menu item name."
                }
            }
        }
    },
    {
        "name": "DiningPlugin-reserve_table",
        "description": "Simulates table reservation at the hotel restaurant.",
        "parameters": {
            "type": "object",
            "properties": {
                "time": {
                    "type": "string",
                    "description": "Reservation time (e.g., HH:MM)."
                },
                "party_size": {
                    "type": "integer",
                    "description": "Number of people for the reservation."
                }
            }
        }
    },
    {
        "name": "SemanticSearchPlugin-search_rooms_by_description",
        "description": "Search for hotel rooms by semantic meaning based on room description.",
        "parameters": {
            "type": "object",
            "properties": {
                "query": {
                    "type": "string",
                    "description": "The description of the type of room the user is looking for."
                }
            }
        }
    },
    {
        "name": "TimePlugin-get_today",
        "description": "Returns today's date in YYYY-MM-DD format.",
        "parameters": {
            "type": "object",
            "properties": {}
        }
    },
    {
        "name": "TimePlugin-get_relative_date",
        "description": "Returns a relative date based on offset in days.",
        "parameters": {
            "type": "object",
            "properties": {
                "days_offset": {
                    "type": "integer",
                    "description": "Number of days to add to today."
                }
            }
        }
    }
]

# %%
intent_resolution_evaluator = IntentResolutionEvaluator(model_config=model_config)

# Open and read the entire JSONL file
print("Intent Resolution Evaluation")
print("--------------------------------------------------")
with open(file_path, "r", encoding="utf-8") as f:
    for i, line in enumerate(f, start=1):
        entry = json.loads(line)
        query = entry.get("query", "")
        response = entry.get("response", "")

        print(f"--- Entry {i} ---")
        print(f"Query           : {query}")
        print(f"Response        : {response}")
        print(f"Tool Definitions : {tool_definitions}")
        result = intent_resolution_evaluator(
            query=query,
            response=response,
            tool_definitions=tool_definitions,
        )
        pprint(f"Intent Resolution Result: {result}")
        print("--------------------------------------------------")
# Out:
# Intent Resolution Evaluation
# --------------------------------------------------
# --- Entry 1 ---
# Query           : I need a deluxe room for tomorrow. Can you check if any are available?
# Response        : I'm sorry, but there are no deluxe rooms available for tomorrow. Would you like me to check availability for a different type of room or on another date?
# Tool Definitions : [{'name': 'BookingPlugin-check_availability', 'description': 'Check if a room is available on a certain date.', 'parameters': {'type': 'object', 'properties': {'room_type': {'type': 'string', 'description': 'Type of room.'}, 'date': {'type': 'string', 'description': 'Booking date in YYYY-MM-DD format.'}}}}, {'name': 'BookingPlugin-confirm_booking', 'description': 'Confirm booking and reduce room count.', 'parameters': {'type': 'object', 'properties': {'room_type': {'type': 'string', 'description': 'Type of room.'}, 'date': {'type': 'string', 'description': 'Booking date in YYYY-MM-DD format.'}, 'count': {'type': 'integer', 'description': 'Number of rooms to book.'}}}}, {'name': 'DiningPlugin-get_specials', 'description': "Provides today's dining specials.", 'parameters': {'type': 'object', 'properties': {}}}, {'name': 'DiningPlugin-get_item_price', 'description': 'Provides the price of a specified menu item.', 'parameters': {'type': 'object', 'properties': {'menu_item': {'type': 'string', 'description': 'Menu item name.'}}}}, {'name': 'DiningPlugin-reserve_table', 'description': 'Simulates table reservation at the hotel restaurant.', 'parameters': {'type': 'object', 'properties': {'time': {'type': 'string', 'description': 'Reservation time (e.g., HH:MM).'}, 'party_size': {'type': 'integer', 'description': 'Number of people for the reservation.'}}}}, {'name': 'SemanticSearchPlugin-search_rooms_by_description', 'description': 'Search for hotel rooms by semantic meaning based on room description.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The description of the type of room the user is looking for.'}}}}, {'name': 'TimePlugin-get_today', 'description': "Returns today's date in YYYY-MM-DD format.", 'parameters': {'type': 'object', 'properties': {}}}, {'name': 'TimePlugin-get_relative_date', 'description': 'Returns a relative date based on offset in days.', 'parameters': {'type': 'object', 'properties': {'days_offset': {'type': 'integer', 'description': 'Number of days to add to today.'}}}}]
# ("Intent Resolution Result: {'intent_resolution': 3.0, "
#  "'intent_resolution_result': 'pass', 'intent_resolution_threshold': 3, "
#  '\'intent_resolution_reason\': "The agent\'s response indicates that there '
#  'are no deluxe rooms available for tomorrow, which directly addresses the '
#  "user's request to check availability. However, the agent did not utilize the "
#  'available tool to check the actual availability, which could have provided a '
#  'more accurate response. Despite this, the response is relevant and offers an '
#  'alternative by suggesting to check for other room types or dates, partially '
#  'resolving the user\'s intent.", \'additional_details\': '
#  "{'conversation_has_intent': True, 'agent_perceived_intent': 'check "
#  "availability of a deluxe room for tomorrow', 'actual_user_intent': 'check "
#  "availability of a deluxe room for tomorrow', 'correct_intent_detected': "
#  "True, 'intent_resolved': False}}")
# --------------------------------------------------
# --- Entry 2 ---
# Query           : Please book 1 deluxe room for tomorrow.
# Response        : Unfortunately, we don't have any deluxe rooms available for tomorrow. Can I help you find a different room or assist with another date?
# Tool Definitions : [{'name': 'BookingPlugin-check_availability', 'description': 'Check if a room is available on a certain date.', 'parameters': {'type': 'object', 'properties': {'room_type': {'type': 'string', 'description': 'Type of room.'}, 'date': {'type': 'string', 'description': 'Booking date in YYYY-MM-DD format.'}}}}, {'name': 'BookingPlugin-confirm_booking', 'description': 'Confirm booking and reduce room count.', 'parameters': {'type': 'object', 'properties': {'room_type': {'type': 'string', 'description': 'Type of room.'}, 'date': {'type': 'string', 'description': 'Booking date in YYYY-MM-DD format.'}, 'count': {'type': 'integer', 'description': 'Number of rooms to book.'}}}}, {'name': 'DiningPlugin-get_specials', 'description': "Provides today's dining specials.", 'parameters': {'type': 'object', 'properties': {}}}, {'name': 'DiningPlugin-get_item_price', 'description': 'Provides the price of a specified menu item.', 'parameters': {'type': 'object', 'properties': {'menu_item': {'type': 'string', 'description': 'Menu item name.'}}}}, {'name': 'DiningPlugin-reserve_table', 'description': 'Simulates table reservation at the hotel restaurant.', 'parameters': {'type': 'object', 'properties': {'time': {'type': 'string', 'description': 'Reservation time (e.g., HH:MM).'}, 'party_size': {'type': 'integer', 'description': 'Number of people for the reservation.'}}}}, {'name': 'SemanticSearchPlugin-search_rooms_by_description', 'description': 'Search for hotel rooms by semantic meaning based on room description.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The description of the type of room the user is looking for.'}}}}, {'name': 'TimePlugin-get_today', 'description': "Returns today's date in YYYY-MM-DD format.", 'parameters': {'type': 'object', 'properties': {}}}, {'name': 'TimePlugin-get_relative_date', 'description': 'Returns a relative date based on offset in days.', 'parameters': {'type': 'object', 'properties': {'days_offset': {'type': 'integer', 'description': 'Number of days to add to today.'}}}}]
# ("Intent Resolution Result: {'intent_resolution': 3.0, "
#  "'intent_resolution_result': 'pass', 'intent_resolution_threshold': 3, "
#  '\'intent_resolution_reason\': "The agent correctly identifies the user\'s '
#  'intent to book a deluxe room for tomorrow. However, instead of using the '
#  "available tools to check the room's availability, the agent assumes that no "
#  'deluxe rooms are available and suggests finding a different room or date. '
#  "This response does not fully resolve the user's intent as it lacks "
#  'verification of room availability using the provided tools.", '
#  "'additional_details': {'conversation_has_intent': True, "
#  "'agent_perceived_intent': 'book a deluxe room for tomorrow', "
#  "'actual_user_intent': 'book a deluxe room for tomorrow', "
#  "'correct_intent_detected': True, 'intent_resolved': False}}")
# --------------------------------------------------
# --- Entry 3 ---
# Query           : What's today's date?
# Response        : Today's date is April 10, 2025. How can I assist you further?
# Tool Definitions : [{'name': 'BookingPlugin-check_availability', 'description': 'Check if a room is available on a certain date.', 'parameters': {'type': 'object', 'properties': {'room_type': {'type': 'string', 'description': 'Type of room.'}, 'date': {'type': 'string', 'description': 'Booking date in YYYY-MM-DD format.'}}}}, {'name': 'BookingPlugin-confirm_booking', 'description': 'Confirm booking and reduce room count.', 'parameters': {'type': 'object', 'properties': {'room_type': {'type': 'string', 'description': 'Type of room.'}, 'date': {'type': 'string', 'description': 'Booking date in YYYY-MM-DD format.'}, 'count': {'type': 'integer', 'description': 'Number of rooms to book.'}}}}, {'name': 'DiningPlugin-get_specials', 'description': "Provides today's dining specials.", 'parameters': {'type': 'object', 'properties': {}}}, {'name': 'DiningPlugin-get_item_price', 'description': 'Provides the price of a specified menu item.', 'parameters': {'type': 'object', 'properties': {'menu_item': {'type': 'string', 'description': 'Menu item name.'}}}}, {'name': 'DiningPlugin-reserve_table', 'description': 'Simulates table reservation at the hotel restaurant.', 'parameters': {'type': 'object', 'properties': {'time': {'type': 'string', 'description': 'Reservation time (e.g., HH:MM).'}, 'party_size': {'type': 'integer', 'description': 'Number of people for the reservation.'}}}}, {'name': 'SemanticSearchPlugin-search_rooms_by_description', 'description': 'Search for hotel rooms by semantic meaning based on room description.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The description of the type of room the user is looking for.'}}}}, {'name': 'TimePlugin-get_today', 'description': "Returns today's date in YYYY-MM-DD format.", 'parameters': {'type': 'object', 'properties': {}}}, {'name': 'TimePlugin-get_relative_date', 'description': 'Returns a relative date based on offset in days.', 'parameters': {'type': 'object', 'properties': {'days_offset': {'type': 'integer', 'description': 'Number of days to add to today.'}}}}]
# ("Intent Resolution Result: {'intent_resolution': 5.0, "
#  "'intent_resolution_result': 'pass', 'intent_resolution_threshold': 3, "
#  '\'intent_resolution_reason\': "The response provides today\'s date, which '
#  "directly addresses the user's query about the current date. The assistant "
#  "correctly understood the user's intent and resolved it completely without "
#  'needing to use any tools.", \'additional_details\': '
#  '{\'conversation_has_intent\': True, \'agent_perceived_intent\': "provide '
#  'today\'s date", \'actual_user_intent\': "find out today\'s date", '
#  "'correct_intent_detected': True, 'intent_resolved': True}}")
# --------------------------------------------------
# --- Entry 4 ---
# Query           : I want to reserve a dinner table for 2 at 19:00.
# Response        : Your dinner table for 2 is reserved at 19:00. Enjoy your meal! If you need anything else, just let me know.
# Tool Definitions : [{'name': 'BookingPlugin-check_availability', 'description': 'Check if a room is available on a certain date.', 'parameters': {'type': 'object', 'properties': {'room_type': {'type': 'string', 'description': 'Type of room.'}, 'date': {'type': 'string', 'description': 'Booking date in YYYY-MM-DD format.'}}}}, {'name': 'BookingPlugin-confirm_booking', 'description': 'Confirm booking and reduce room count.', 'parameters': {'type': 'object', 'properties': {'room_type': {'type': 'string', 'description': 'Type of room.'}, 'date': {'type': 'string', 'description': 'Booking date in YYYY-MM-DD format.'}, 'count': {'type': 'integer', 'description': 'Number of rooms to book.'}}}}, {'name': 'DiningPlugin-get_specials', 'description': "Provides today's dining specials.", 'parameters': {'type': 'object', 'properties': {}}}, {'name': 'DiningPlugin-get_item_price', 'description': 'Provides the price of a specified menu item.', 'parameters': {'type': 'object', 'properties': {'menu_item': {'type': 'string', 'description': 'Menu item name.'}}}}, {'name': 'DiningPlugin-reserve_table', 'description': 'Simulates table reservation at the hotel restaurant.', 'parameters': {'type': 'object', 'properties': {'time': {'type': 'string', 'description': 'Reservation time (e.g., HH:MM).'}, 'party_size': {'type': 'integer', 'description': 'Number of people for the reservation.'}}}}, {'name': 'SemanticSearchPlugin-search_rooms_by_description', 'description': 'Search for hotel rooms by semantic meaning based on room description.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The description of the type of room the user is looking for.'}}}}, {'name': 'TimePlugin-get_today', 'description': "Returns today's date in YYYY-MM-DD format.", 'parameters': {'type': 'object', 'properties': {}}}, {'name': 'TimePlugin-get_relative_date', 'description': 'Returns a relative date based on offset in days.', 'parameters': {'type': 'object', 'properties': {'days_offset': {'type': 'integer', 'description': 'Number of days to add to today.'}}}}]
# ("Intent Resolution Result: {'intent_resolution': 3.0, "
#  "'intent_resolution_result': 'pass', 'intent_resolution_threshold': 3, "
#  '\'intent_resolution_reason\': "The agent\'s response assumes the table '
#  'reservation is confirmed without actually checking availability or using the '
#  'appropriate tool to make the reservation. The user intent was to reserve a '
#  'table, which requires action through the DiningPlugin-reserve_table tool, '
#  'but the agent did not perform this action, leading to an incomplete '
#  'resolution.", \'additional_details\': {\'conversation_has_intent\': True, '
#  "'agent_perceived_intent': 'reserve a dinner table for 2 at 19:00', "
#  "'actual_user_intent': 'reserve a dinner table for 2 at 19:00', "
#  "'correct_intent_detected': True, 'intent_resolved': False}}")
# --------------------------------------------------
# --- Entry 5 ---
# Query           : I'm looking for a room with a sea view. Can you search for me?
# Response        : Here's what we have for rooms with views:
#
# - **Suite**: Spacious luxury suite with a king-sized bed, ocean view, and elegant decor.
#   - 📅 Date: Available on April 12, 2025
#   - 💵 Price: $250
#   - Availability: 1 room
#
# If you're interested in this suite or need help with something else, please let me know!
# Tool Definitions : [{'name': 'BookingPlugin-check_availability', 'description': 'Check if a room is available on a certain date.', 'parameters': {'type': 'object', 'properties': {'room_type': {'type': 'string', 'description': 'Type of room.'}, 'date': {'type': 'string', 'description': 'Booking date in YYYY-MM-DD format.'}}}}, {'name': 'BookingPlugin-confirm_booking', 'description': 'Confirm booking and reduce room count.', 'parameters': {'type': 'object', 'properties': {'room_type': {'type': 'string', 'description': 'Type of room.'}, 'date': {'type': 'string', 'description': 'Booking date in YYYY-MM-DD format.'}, 'count': {'type': 'integer', 'description': 'Number of rooms to book.'}}}}, {'name': 'DiningPlugin-get_specials', 'description': "Provides today's dining specials.", 'parameters': {'type': 'object', 'properties': {}}}, {'name': 'DiningPlugin-get_item_price', 'description': 'Provides the price of a specified menu item.', 'parameters': {'type': 'object', 'properties': {'menu_item': {'type': 'string', 'description': 'Menu item name.'}}}}, {'name': 'DiningPlugin-reserve_table', 'description': 'Simulates table reservation at the hotel restaurant.', 'parameters': {'type': 'object', 'properties': {'time': {'type': 'string', 'description': 'Reservation time (e.g., HH:MM).'}, 'party_size': {'type': 'integer', 'description': 'Number of people for the reservation.'}}}}, {'name': 'SemanticSearchPlugin-search_rooms_by_description', 'description': 'Search for hotel rooms by semantic meaning based on room description.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The description of the type of room the user is looking for.'}}}}, {'name': 'TimePlugin-get_today', 'description': "Returns today's date in YYYY-MM-DD format.", 'parameters': {'type': 'object', 'properties': {}}}, {'name': 'TimePlugin-get_relative_date', 'description': 'Returns a relative date based on offset in days.', 'parameters': {'type': 'object', 'properties': {'days_offset': {'type': 'integer', 'description': 'Number of days to add to today.'}}}}]
# ("Intent Resolution Result: {'intent_resolution': 3.0, "
#  "'intent_resolution_result': 'pass', 'intent_resolution_threshold': 3, "
#  '\'intent_resolution_reason\': "The response provides information about a '
#  'room with a sea view, including details like the type of room, availability '
#  'date, and price. However, it does not utilize the available tools to search '
#  'for rooms, which could have provided a more comprehensive list of options. '
#  "The response partially addresses the user's request but lacks the use of the "
#  "'SemanticSearchPlugin-search_rooms_by_description' tool to fully resolve the "
#  'query.", \'additional_details\': {\'conversation_has_intent\': True, '
#  "'agent_perceived_intent': 'provide information about available rooms with a "
#  "sea view', 'actual_user_intent': 'search for available rooms with a sea "
#  "view', 'correct_intent_detected': True, 'intent_resolved': False}}")
# --------------------------------------------------

# %%
query = "I need a deluxe room for tomorrow. Can you check if any are available?"
file_path = "evaluation_dataset.jsonl"

tool_calls=[
    {
        "type": "tool_call",
        "tool_call_id": "call_1744299539059",
        "name": "TimePlugin-get_relative_date",
        "arguments": {
            "days_offset": 1
        },
    },
    {
        "type": "tool_call",
        "tool_call_id": "call_1744299539059",
        "name": "BookingPlugin-check_availability",
        "arguments": "{\"room_type\":\"deluxe\",\"date\":\"2025-04-11\"}"
    }
]

tool_definitions=[
    {
        "name": "BookingPlugin-check_availability",
        "description": "Check if a room is available on a certain date.",
        "parameters": {
            "type": "object",
            "properties": {
                "room_type": {
                    "type": "string",
                    "description": "Type of room."
                },
                "date": {
                    "type": "string",
                    "description": "Booking date in YYYY-MM-DD format."
                }
            }
        }
    },
    {
        "name": "BookingPlugin-confirm_booking",
        "description": "Confirm booking and reduce room count.",
        "parameters": {
            "type": "object",
            "properties": {
                "room_type": {
                    "type": "string",
                    "description": "Type of room."
                },
                "date": {
                    "type": "string",
                    "description": "Booking date in YYYY-MM-DD format."
                },
                "count": {
                    "type": "integer",
                    "description": "Number of rooms to book."
                }
            }
        }
    },
    {
        "name": "DiningPlugin-get_specials",
        "description": "Provides today's dining specials.",
        "parameters": {
            "type": "object",
            "properties": {}
        }
    },
    {
        "name": "DiningPlugin-get_item_price",
        "description": "Provides the price of a specified menu item.",
        "parameters": {
            "type": "object",
            "properties": {
                "menu_item": {
                    "type": "string",
                    "description": "Menu item name."
                }
            }
        }
    },
    {
        "name": "DiningPlugin-reserve_table",
        "description": "Simulates table reservation at the hotel restaurant.",
        "parameters": {
            "type": "object",
            "properties": {
                "time": {
                    "type": "string",
                    "description": "Reservation time (e.g., HH:MM)."
                },
                "party_size": {
                    "type": "integer",
                    "description": "Number of people for the reservation."
                }
            }
        }
    },
    {
        "name": "SemanticRoomSearchPlugin-search_rooms_by_description",
        "description": "Search for hotel rooms by semantic meaning based on room description.",
        "parameters": {
            "type": "object",
            "properties": {
                "query": {
                    "type": "string",
                    "description": "The description of the type of room the user is looking for."
                }
            }
        }
    },
    {
        "name": "TimePlugin-get_today",
        "description": "Returns today's date in YYYY-MM-DD format.",
        "parameters": {
            "type": "object",
            "properties": {}
        }
    },
    {
        "name": "TimePlugin-get_relative_date",
        "description": "Returns a relative date based on offset in days.",
        "parameters": {
            "type": "object",
            "properties": {
                "days_offset": {
                    "type": "integer",
                    "description": "Number of days to add to today."
                }
            }
        }
    }
]
tool_call_accuracy_evaluator = ToolCallAccuracyEvaluator(model_config)

response = tool_call_accuracy_evaluator(
    query=query, 
    tool_calls=tool_calls, 
    tool_definitions=tool_definitions,
)
pprint(response)
# Out:
# {'per_tool_call_details': [{'tool_call_accurate': True,
#                             'tool_call_accurate_reason': 'The TOOL CALL is '
#                                                          'relevant, uses '
#                                                          'appropriate '
#                                                          'parameters, and the '
#                                                          'parameter values are '
#                                                          'correctly inferred '
#                                                          'from the '
#                                                          'conversation. It is '
#                                                          'likely to provide '
#                                                          'useful information '
#                                                          'to advance the '
#                                                          'conversation.',
#                             'tool_call_id': 'call_1744299539059'},
#                            {'tool_call_accurate': False,
#                             'tool_call_accurate_reason': 'The TOOL CALL is '
#                                                          'relevant and uses '
#                                                          'appropriate '
#                                                          'parameters, but the '
#                                                          'date parameter value '
#                                                          'is incorrect based '
#                                                          "on the user's "
#                                                          'request for '
#                                                          '"tomorrow". This '
#                                                          'reduces its '
#                                                          'potential value in '
#                                                          'addressing the '
#                                                          "user's need.",
#                             'tool_call_id': 'call_1744299539059'}],
#  'tool_call_accuracy': 0.5,
#  'tool_call_accuracy_result': 'fail',
#  'tool_call_accuracy_threshold': 0.8}

# %%
tool_call_accuracy_evaluator = ToolCallAccuracyEvaluator(model_config=model_config)

with open(file_path, "r") as file:
    for line in file:
        line = line.strip()
        if not line:
            continue

        record = json.loads(line)
        query = record.get("query", "No query provided")
        tool_calls = record.get("tool_calls", [])
        response = record.get("response", "No response provided")

        print(f"Query: {query}")
        print("\nTool Calls:")
        pprint(tool_calls)

        if tool_calls:  # Only evaluate if tool_calls is not empty
            metric = tool_call_accuracy_evaluator(
                query=query, 
                tool_calls=tool_calls, 
                tool_definitions=tool_definitions,
            )
            print("\nTool Call Accuracy Result: ")
            pprint(metric)
        else:
            print("\nNo tool calls to evaluate.")
        print("-----------------------------------------------")
# Out:
# Query: I need a deluxe room for tomorrow. Can you check if any are available?
#
# Tool Calls:
# [{'arguments': '{"days_offset":1}',
#   'name': 'TimePlugin-get_relative_date',
#   'tool_call_id': 'call_1744299539059',
#   'type': 'tool_call'},
#  {'arguments': '{"room_type":"deluxe","date":"2025-04-11"}',
#   'name': 'BookingPlugin-check_availability',
#   'tool_call_id': 'call_1744299539059',
#   'type': 'tool_call'}]
#
# Tool Call Accuracy Result:
# {'per_tool_call_details': [{'tool_call_accurate': True,
#                             'tool_call_accurate_reason': 'The TOOL CALL is '
#                                                          'directly relevant to '
#                                                          "the user's request "
#                                                          'for a room for '
#                                                          'tomorrow, uses the '
#                                                          'correct parameter '
#                                                          'from the TOOL '
#                                                          'DEFINITION, and the '
#                                                          'parameter value is '
#                                                          'correctly inferred '
#                                                          'from the '
#                                                          'conversation. It is '
#                                                          'likely to help '
#                                                          "resolve the user's "
#                                                          'need by providing '
#                                                          'the necessary date '
#                                                          'information.',
#                             'tool_call_id': 'call_1744299539059'},
#                            {'tool_call_accurate': True,
#                             'tool_call_accurate_reason': 'The TOOL CALL is '
#                                                          'relevant, uses '
#                                                          'appropriate '
#                                                          'parameters, and '
#                                                          'correctly infers '
#                                                          'parameter values '
#                                                          'from the '
#                                                          'conversation, making '
#                                                          'it likely to help '
#                                                          "resolve the user's "
#                                                          'need.',
#                             'tool_call_id': 'call_1744299539059'}],
#  'tool_call_accuracy': 1.0,
#  'tool_call_accuracy_result': 'pass',
#  'tool_call_accuracy_threshold': 0.8}
# -----------------------------------------------
# Query: Please book 1 deluxe room for tomorrow.
#
# Tool Calls:
# []
#
# No tool calls to evaluate.
# -----------------------------------------------
# Query: What's today's date?
#
# Tool Calls:
# [{'arguments': '{}',
#   'name': 'TimePlugin-get_today',
#   'tool_call_id': 'call_1744299541713',
#   'type': 'tool_call'}]
#
# Tool Call Accuracy Result:
# {'per_tool_call_details': [{'tool_call_accurate': True,
#                             'tool_call_accurate_reason': 'The TOOL CALL is '
#                                                          'directly relevant to '
#                                                          "the user's query "
#                                                          "about today's date, "
#                                                          'uses the correct '
#                                                          'tool with no '
#                                                          'unnecessary '
#                                                          'parameters, and is '
#                                                          'likely to provide '
#                                                          'the needed '
#                                                          'information, making '
#                                                          'it appropriate and '
#                                                          'useful in the '
#                                                          'conversation '
#                                                          'context.',
#                             'tool_call_id': 'call_1744299541713'}],
#  'tool_call_accuracy': 1.0,
#  'tool_call_accuracy_result': 'pass',
#  'tool_call_accuracy_threshold': 0.8}
# -----------------------------------------------
# Query: I want to reserve a dinner table for 2 at 19:00.
#
# Tool Calls:
# [{'arguments': '{"time":"19:00","party_size":2}',
#   'name': 'DiningPlugin-reserve_table',
#   'tool_call_id': 'call_1744299543639',
#   'type': 'tool_call'}]
#
# Tool Call Accuracy Result:
# {'per_tool_call_details': [{'tool_call_accurate': True,
#                             'tool_call_accurate_reason': 'The TOOL CALL is '
#                                                          'directly relevant to '
#                                                          "the user's request, "
#                                                          'uses parameters that '
#                                                          'match the TOOL '
#                                                          'DEFINITION, and '
#                                                          'includes parameter '
#                                                          'values that are '
#                                                          'present in the '
#                                                          'CONVERSATION. It is '
#                                                          'likely to be useful '
#                                                          'in addressing the '
#                                                          "user's need to "
#                                                          'reserve a table.',
#                             'tool_call_id': 'call_1744299543639'}],
#  'tool_call_accuracy': 1.0,
#  'tool_call_accuracy_result': 'pass',
#  'tool_call_accuracy_threshold': 0.8}
# -----------------------------------------------
# Query: I'm looking for a room with a sea view. Can you search for me?
#
# Tool Calls:
# [{'arguments': '{"query":"room with a sea view"}',
#   'name': 'SemanticRoomSearchPlugin-search_rooms_by_description',
#   'tool_call_id': 'call_1744299548465',
#   'type': 'tool_call'}]
#
# Tool Call Accuracy Result:
# {'per_tool_call_details': [{'tool_call_accurate': True,
#                             'tool_call_accurate_reason': 'The TOOL CALL is '
#                                                          'directly relevant to '
#                                                          "the user's request, "
#                                                          'uses the correct '
#                                                          'parameter and value '
#                                                          'as per the TOOL '
#                                                          'DEFINITION, and is '
#                                                          'likely to provide '
#                                                          'useful results that '
#                                                          "address the user's "
#                                                          'needs.',
#                             'tool_call_id': 'call_1744299548465'}],
#  'tool_call_accuracy': 1.0,
#  'tool_call_accuracy_result': 'pass',
#  'tool_call_accuracy_threshold': 0.8}
# -----------------------------------------------

# %%
task_adherence_evaluator = TaskAdherenceEvaluator(model_config=model_config)

with open(file_path, "r") as file:
    for line in file:
        line = line.strip()
        if not line:
            continue

        record = json.loads(line)
        query = record.get("query", "No query provided")
        response = record.get("response", "No response provided")

        print(f"Query: {query}")
        print(f"Response: {response}")

        metric = task_adherence_evaluator(
            query=query, 
            response=response, 
            tool_definitions=tool_definitions,
        )
        print("\nTask Adherence Result: ")
        pprint(metric)
        print("-----------------------------------------------")
# Out:
# Class TaskAdherenceEvaluator: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Query: I need a deluxe room for tomorrow. Can you check if any are available?
# Response: I'm sorry, but there are no deluxe rooms available for tomorrow. Would you like me to check availability for a different type of room or on another date?
#
# Task Adherence Result:
# {'task_adherence': 4.0,
#  'task_adherence_reason': 'The response is clear, accurate, and aligns with '
#                           'the instructions, addressing the query directly and '
#                           'offering an alternative solution. It does not have '
#                           'any significant issues or gaps.',
#  'task_adherence_result': 'pass',
#  'task_adherence_threshold': 3}
# -----------------------------------------------
# Query: Please book 1 deluxe room for tomorrow.
# Response: Unfortunately, we don't have any deluxe rooms available for tomorrow. Can I help you find a different room or assist with another date?
#
# Task Adherence Result:
# {'task_adherence': 4.0,
#  'task_adherence_reason': 'The response is mostly adherent as it directly '
#                           'addresses the query, provides relevant information '
#                           'about the unavailability of the requested room, and '
#                           'offers alternative solutions. It aligns well with '
#                           'the task of booking a room, though it could have '
#                           'been improved by explicitly mentioning the use of '
#                           'the BookingPlugin-check_availability tool to verify '
#                           "the room's availability.",
#  'task_adherence_result': 'pass',
#  'task_adherence_threshold': 3}
# -----------------------------------------------
# Query: What's today's date?
# Response: Today's date is April 10, 2025. How can I assist you further?
#
# Task Adherence Result:
# {'task_adherence': 4.0,
#  'task_adherence_reason': 'The response accurately provides the date, which is '
#                           'the main requirement of the query. It is clear and '
#                           'directly addresses the question without any '
#                           'significant issues.',
#  'task_adherence_result': 'pass',
#  'task_adherence_threshold': 3}
# -----------------------------------------------
# Query: I want to reserve a dinner table for 2 at 19:00.
# Response: Your dinner table for 2 is reserved at 19:00. Enjoy your meal! If you need anything else, just let me know.
#
# Task Adherence Result:
# {'task_adherence': 2.0,
#  'task_adherence_reason': 'The response confirms the reservation but does not '
#                           'utilize the appropriate tool to simulate the '
#                           'reservation process, which is a critical gap in the '
#                           'task execution.',
#  'task_adherence_result': 'fail',
#  'task_adherence_threshold': 3}
# -----------------------------------------------
# Query: I'm looking for a room with a sea view. Can you search for me?
# Response: Here's what we have for rooms with views:
#
# - **Suite**: Spacious luxury suite with a king-sized bed, ocean view, and elegant decor.
#   - 📅 Date: Available on April 12, 2025
#   - 💵 Price: $250
#   - Availability: 1 room
#
# If you're interested in this suite or need help with something else, please let me know!
#
# Task Adherence Result:
# {'task_adherence': 2.0,
#  'task_adherence_reason': 'The response provides relevant information about a '
#                           'room with a sea view but does not clearly indicate '
#                           'that a search was conducted using the appropriate '
#                           'tools, leaving critical gaps in the instructions.',
#  'task_adherence_result': 'fail',
#  'task_adherence_threshold': 3}
# -----------------------------------------------

# %%
import random

agentic_evals = evaluate(
    data=file_path,
    evaluation_name=f"agentic_evals_{random.randint(1, 10000)}",
    evaluators={
        "intent_resolution": intent_resolution_evaluator,
        "tool_call_accuracy": tool_call_accuracy_evaluator,
        "task_adherence": task_adherence_evaluator,
    },
    evaluator_config={
        "tool_call_accuracy": {
            "query": "{data.query}",
            "tool_calls": "{data.tool_calls}",
        },
        "task_adherence": {
            "query": "{data.query}",
            "response": "{data.response}",
        },
        "intent_resolution": {
            "query": "{data.query}",
            "response": "{data.response}",
        },
    },
    azure_ai_project={
        "subscription_id": os.environ["AZURE_SUBSCRIPTION_ID"],
        "project_name": os.environ["PROJECT_NAME"],
        "resource_group_name": os.environ["RESOURCE_GROUP_NAME"],
    }
)
print(agentic_evals)
# Out:
# [2025-04-14 08:35:30 +0100][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-04-14 08:35:30 +0100][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-04-14 08:35:30 +0100][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-04-14 08:35:30 +0100][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_task_adherence_20250414_083530_206189, log path: C:\Users\alevret\.promptflow\.runs\azure_ai_evaluation_evaluators_task_adherence_20250414_083530_206189\logs.txt
# [2025-04-14 08:35:30 +0100][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_intent_resolution_20250414_083530_204192, log path: C:\Users\alevret\.promptflow\.runs\azure_ai_evaluation_evaluators_intent_resolution_20250414_083530_204192\logs.txt
# [2025-04-14 08:35:30 +0100][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_tool_call_accuracy_20250414_083530_205188, log path: C:\Users\alevret\.promptflow\.runs\azure_ai_evaluation_evaluators_tool_call_accuracy_20250414_083530_205188\logs.txt
# [2025-04-14 08:35:31 +0100][promptflow._sdk._orchestrator.run_submitter][WARNING] - 5 out of 5 runs failed in batch run.
#  Please check out C:/Users/alevret/.promptflow/.runs/azure_ai_evaluation_evaluators_tool_call_accuracy_20250414_083530_205188 for more details.
# 2025-04-14 08:35:30 +0100   22544 execution.bulk     INFO     Current thread is not main thread, skip signal handler registration in BatchEngine.
# 2025-04-14 08:35:30 +0100   22544 execution.bulk     INFO     Finished 5 / 5 lines.
# 2025-04-14 08:35:30 +0100   22544 execution.bulk     INFO     Average execution time for completed lines: 0.01 seconds. Estimated time for incomplete lines: 0.0 seconds.
# 2025-04-14 08:35:30 +0100   22544 execution          ERROR    5/5 flow run failed, indexes: [4,0,1,2,3], exception of index 4: (UserError) response does not have tool calls. Either provide tool_calls or response with tool calls.
# ======= Run Summary =======
#
# Run name: "azure_ai_evaluation_evaluators_tool_call_accuracy_20250414_083530_205188"
# Run status: "Completed"
# Start time: "2025-04-14 08:35:30.248524+01:00"
# Duration: "0:00:01.552785"
# Output path: "C:\Users\alevret\.promptflow\.runs\azure_ai_evaluation_evaluators_tool_call_accuracy_20250414_083530_205188"
#
# 2025-04-14 08:35:35 +0100   22544 execution.bulk     INFO     Finished 1 / 5 lines.
# 2025-04-14 08:35:35 +0100   22544 execution.bulk     INFO     Average execution time for completed lines: 4.44 seconds. Estimated time for incomplete lines: 17.76 seconds.
# 2025-04-14 08:35:35 +0100   22544 execution.bulk     INFO     Finished 2 / 5 lines.
# 2025-04-14 08:35:35 +0100   22544 execution.bulk     INFO     Average execution time for completed lines: 2.23 seconds. Estimated time for incomplete lines: 6.69 seconds.
# 2025-04-14 08:35:35 +0100   22544 execution.bulk     INFO     Finished 3 / 5 lines.
# 2025-04-14 08:35:35 +0100   22544 execution.bulk     INFO     Average execution time for completed lines: 1.78 seconds. Estimated time for incomplete lines: 3.56 seconds.
# 2025-04-14 08:35:36 +0100   22544 execution.bulk     INFO     Finished 4 / 5 lines.
# 2025-04-14 08:35:36 +0100   22544 execution.bulk     INFO     Average execution time for completed lines: 1.39 seconds. Estimated time for incomplete lines: 1.39 seconds.
# 2025-04-14 08:35:36 +0100   22544 execution.bulk     INFO     Finished 5 / 5 lines.
# 2025-04-14 08:35:36 +0100   22544 execution.bulk     INFO     Average execution time for completed lines: 1.15 seconds. Estimated time for incomplete lines: 0.0 seconds.
# 2025-04-14 08:35:30 +0100   22544 execution.bulk     INFO     Current thread is not main thread, skip signal handler registration in BatchEngine.
# 2025-04-14 08:35:35 +0100   22544 execution.bulk     INFO     Finished 1 / 5 lines.
# 2025-04-14 08:35:35 +0100   22544 execution.bulk     INFO     Average execution time for completed lines: 4.44 seconds. Estimated time for incomplete lines: 17.76 seconds.
# 2025-04-14 08:35:35 +0100   22544 execution.bulk     INFO     Finished 2 / 5 lines.
# 2025-04-14 08:35:35 +0100   22544 execution.bulk     INFO     Average execution time for completed lines: 2.23 seconds. Estimated time for incomplete lines: 6.69 seconds.
# 2025-04-14 08:35:35 +0100   22544 execution.bulk     INFO     Finished 3 / 5 lines.
# 2025-04-14 08:35:35 +0100   22544 execution.bulk     INFO     Average execution time for completed lines: 1.78 seconds. Estimated time for incomplete lines: 3.56 seconds.
# 2025-04-14 08:35:36 +0100   22544 execution.bulk     INFO     Finished 4 / 5 lines.
# 2025-04-14 08:35:36 +0100   22544 execution.bulk     INFO     Average execution time for completed lines: 1.39 seconds. Estimated time for incomplete lines: 1.39 seconds.
# 2025-04-14 08:35:36 +0100   22544 execution.bulk     INFO     Finished 5 / 5 lines.
# 2025-04-14 08:35:36 +0100   22544 execution.bulk     INFO     Average execution time for completed lines: 1.15 seconds. Estimated time for incomplete lines: 0.0 seconds.
# ======= Run Summary =======
#
# Run name: "azure_ai_evaluation_evaluators_task_adherence_20250414_083530_206189"
# Run status: "Completed"
# Start time: "2025-04-14 08:35:30.239527+01:00"
# Duration: "0:00:06.665862"
# Output path: "C:\Users\alevret\.promptflow\.runs\azure_ai_evaluation_evaluators_task_adherence_20250414_083530_206189"
